# %% [markdown]
# https://www.youtube.com/watch?v=SwSbnmqk3zY
# https://www.youtube.com/watch?v=ZspR5PZemcs

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %% [markdown]
# Cara:
# - Bikin google youtube api credential di "google console" web
# - copy kredensialnya ke variabel api_key
# - Di langkah 2 masukin keyword dari kumpulan video yang hendak dicari
#
# notes:
# - youtube api request ada quotanya, kalau quota exceed, bikin project baru trus buat ulang credentialnya

# %%
api_key = "AIzaSyA-_PwToNnmGW7wkJka-95oH0c9EJitZtc" # Ubah ini
youtube = build("youtube","v3",developerKey=api_key)

# %% [markdown]
# ## 1. Fungsi untuk mendapatkan statistik channel

# %%
# ## Per channel
# ## Ga digunain
# def get_channel_stats(yt,ch_ids):
#     request = yt.channels().list(
#                 part = "snippet,contentDetails,statistics",
#         id=",".join(ch_ids)
#     )
#     response = request.execute()
#     datas=[]
#     for i in range(len(response["items"])):
#         data = dict(channelName = response["items"][i]["snippet"]["title"],
#                     subscribers = response["items"][i]["statistics"]["subscriberCount"],
#                     views = response["items"][i]["statistics"]["viewCount"],
#                     totalVideo = response["items"][i]["statistics"]["videoCount"]
#                    )
#         datas.append(data)
    
#     return datas

# Per Keyword Search

##Versi Full
# def get_channel_stats_keyword(key,max ,yt):
#     request = yt.search().list(
#         q = key,
#         part = "snippet",
#         type="video",
#         maxResults = (max) 
#     )
#     response = request.execute()
#     datas=[]

#     # print("jumlah video: ",len(response["items"]))
#     # print("jumlah video: ",(response["items"][0]))
#     for j in range(len(response["items"])):
#         vidId = response["items"][j]["id"]["videoId"]
#         # print(response["items"][j])
#         response_stats = yt.videos().list(part = "statistics",id=vidId).execute()

#         # print(response_stats["items"])
#         for i in range(len(response_stats["items"])):
#             data = dict(videoId = vidId,
#                         metaData = response["items"][j],
#                         viewCount = response_stats["items"][i]["statistics"]["viewCount"],
#                         likeCount = response_stats["items"][i]["statistics"]["likeCount"],
#                         commentCount = response_stats["items"][i]["statistics"]["likeCount"]
#                     )
#             datas.append(data)
#     return datas

#Versi nurutin movies.csv movielens
def get_channel_stats_keyword(key,max ,yt):
    request = yt.search().list(
        q = key,
        part = "snippet",
        type="video",
        maxResults = (max) 
    )
    response = request.execute()
    datas=[]

    # print("jumlah video: ",len(response["items"]))
    # print("jumlah video: ",(response["items"][0]))
    for j in range(len(response["items"])):
        vidId = response["items"][j]["id"]["videoId"]
        # print(response["items"][j])
        response_stats = yt.videos().list(part = "statistics",id=vidId).execute()

        # print(response_stats["items"])
        for i in range(len(response_stats["items"])):
            data = dict(videoId = vidId,
                        title = response["items"][j]["snippet"]["title"],
                        genres = [keyword],
                        metaData = response["items"][j]
            )

            datas.append(data)
    return datas

# %% [markdown]
# ## 2. Mulai Cari Video Berdasarkan Keyword

# %%
keywords = ["Digital Marketing",
            "quality control umkm",
            "cara penggunaan ecommerce",
            "desain kemasan umkm"
            ]
jsonDatas=[]
for keyword in keywords:
    jsonData = ((get_channel_stats_keyword(keyword,50,youtube)))
    frame = pd.DataFrame(jsonData)
    jsonDatas.append(frame)
df = pd.concat (jsonDatas)

# %%
df.to_csv (r'umkm.csv', index = None)

# %%
print("Jumlah data: ",len(df))
df.head()
# Out:
# Jumlah data:  200
#        videoId                                              title  \
# 0  gGAA5gxzRoE  Kerangka Ideal Belajar Digital Marketing Untuk...
# 1  vV_FAwiQX6c              APA ITU DIGITAL MARKETING SEBENARNYA?
# 2  evyIJL8_1XE          #BCTalk - Digital Marketing for Beginners
# 3  rFfkVLO90XE           Trend &amp; Fakta Digital Marketing 2022
# 4  tpYYIC3j0NQ  Pakai Digital Marketing Sudah Wajib, Pahami Ko...
#
#                 genres                                           metaData
# 0  [Digital Marketing]  {'kind': 'youtube#searchResult', 'etag': 'ZKZu...
# 1  [Digital Marketing]  {'kind': 'youtube#searchResult', 'etag': 'LRMi...
# 2  [Digital Marketing]  {'kind': 'youtube#searchResult', 'etag': 'WltW...
# 3  [Digital Marketing]  {'kind': 'youtube#searchResult', 'etag': 'twzb...
# 4  [Digital Marketing]  {'kind': 'youtube#searchResult', 'etag': 'hhpP...

# %%
videoId = {}
for i in range(len(df)):
    if len(videoId) == 0:
        videoId[df["videoId"][i]] = df["genres"][i]
    else:
        if df["videoId"][i] in videoId:
            videoId[df["videoId"][i]] = videoId[df["videoId"][i]] + "," + df["genres"][i]
df
# Out:
#         videoId                                              title  \
# 0   gGAA5gxzRoE  Kerangka Ideal Belajar Digital Marketing Untuk...
# 1   vV_FAwiQX6c              APA ITU DIGITAL MARKETING SEBENARNYA?
# 2   evyIJL8_1XE          #BCTalk - Digital Marketing for Beginners
# 3   rFfkVLO90XE           Trend &amp; Fakta Digital Marketing 2022
# 4   tpYYIC3j0NQ  Pakai Digital Marketing Sudah Wajib, Pahami Ko...
# ..          ...                                                ...
# 45  Nh9BneJ16kc  Cara Membuat Desain Kemasan &quot;Coffe KW&quo...
# 46  k1yqkNdd4EM              Desain Kemasan Produk UMKM Cireng Isi
# 47  PbhjRj4fJ_4  CARA MEMBUAT PACKAGING/KEMASAN KUE DAN MAKANAN...
# 48  NN1Cn35M-jA                 Proses Desain Kemasan Warung Sasti
# 49  1q8F5HGr8ZE                     Desain Kemasan dengan InkScape
#
#                    genres                                           metaData
# 0     [Digital Marketing]  {'kind': 'youtube#searchResult', 'etag': 'ZKZu...
# 1     [Digital Marketing]  {'kind': 'youtube#searchResult', 'etag': 'LRMi...
# 2     [Digital Marketing]  {'kind': 'youtube#searchResult', 'etag': 'WltW...
# 3     [Digital Marketing]  {'kind': 'youtube#searchResult', 'etag': 'twzb...
# 4     [Digital Marketing]  {'kind': 'youtube#searchResult', 'etag': 'hhpP...
# ..                    ...                                                ...
# 45  [desain kemasan umkm]  {'kind': 'youtube#searchResult', 'etag': 'vikJ...
# 46  [desain kemasan umkm]  {'kind': 'youtube#searchResult', 'etag': 'doP_...
# 47  [desain kemasan umkm]  {'kind': 'youtube#searchResult', 'etag': '0Xyx...
# 48  [desain kemasan umkm]  {'kind': 'youtube#searchResult', 'etag': 'tOJZ...
# 49  [desain kemasan umkm]  {'kind': 'youtube#searchResult', 'etag': 'xVL-...
#
# [200 rows x 4 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Muhammad Nur Ilmi\OneDrive\Dokumen\Bangkit\Bangkit2022\Caspstone\BUMI-Machine-Learning\YT Scrapping\Scrapping200.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Muhammad%20Nur%20Ilmi/OneDrive/Dokumen/Bangkit/Bangkit2022/Caspstone/BUMI-Machine-Learning/YT%20Scrapping/Scrapping200.ipynb#ch0000013?line=0'>1</a> print(json.loads("{}"))
#
# NameError: name 'json' is not defined
